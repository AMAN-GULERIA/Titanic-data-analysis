# %%
#Import libraries That we have installed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dp = pd.read_csv(r'C:\Users\amans\Downloads\train.csv')

# %%
dp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

# %%
dp = pd.read_csv('train.csv')

# %%
df = dp.copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# identyfying Data cleaning issues
#
# (1) There are nan values in age column.
#
# (2) we need not required columns like passengerld, name , cabin and ticket.
#
# (3) Apart from survived column having values '0' and '1',Creating a new column with class/categolical status of suvival needed mentioning 'Survivied' or 'Did not Survived'
#
# (4)Fare value i.e. 512.32 in the dataset is an outlier

# %%
print('Mean Fare is', df['Fare'].mean())
print('Minium Fare is', df['Fare'].min())
print('Maximum is', df['Fare'].max())
# Out:
# Mean Fare is 32.2042079685746
# Minium Fare is 0.0
# Maximum is 512.3292

# %%
df = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis = 1)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    float64
#  7   Embarked  712 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB

# %%
df['Survival_Status'] = df['Survived'].replace({1: 'Survived', 0: 'Did not Survived'})

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
#
#     Survival_Status
# 0  Did not Survived
# 1          Survived
# 2          Survived
# 3          Survived
# 4  Did not Survived

# %%
df = df[df['Fare'] < 512]

# %%
df[df['Fare'] > 300]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked, Survival_Status]
# Index: []

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 885         0       3  female  39.0      0      5  29.1250        Q
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#       Survival_Status
# 0    Did not Survived
# 1            Survived
# 2            Survived
# 3            Survived
# 4    Did not Survived
# ...

# %%
df.to_csv('Titanic.csv')

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
#
#     Survival_Status
# 0  Did not Survived
# 1          Survived
# 2          Survived
# 3          Survived
# 4  Did not Survived

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  709.000000  709.000000  709.000000  709.000000  709.000000  709.000000
# mean     0.401975    2.245416   29.618011    0.516220    0.433004   32.545692
# std      0.490643    0.834714   14.518828    0.932059    0.855415   42.931277
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   15.500000
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   32.320800
# max      1.000000    3.000000   80.000000    5.000000    6.000000  263.000000

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.351579 -0.084756 -0.012733  0.096227  0.272376
# Pclass   -0.351579  1.000000 -0.365259  0.062048  0.023059 -0.616062
# Age      -0.084756 -0.365259  1.000000 -0.306731 -0.187967  0.096573
# SibSp    -0.012733  0.062048 -0.306731  1.000000  0.383571  0.199056
# Parch     0.096227  0.023059 -0.187967  0.383571  1.000000  0.260993
# Fare      0.272376 -0.616062  0.096573  0.199056  0.260993  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %matplotlib inline

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7c4bd5eaeb79> in <module>
#       1 fig = plt.figure(figsize=[8,5])
# ----> 2 color_palette = sb.color_palette()[0]
#       3 ordered = df['Pclass'].value_counts().index
#       4 sb.countplot(data = df, x = 'pclass', color = color-palette, order = ordered)
#
# NameError: name 'sb' is not defined
